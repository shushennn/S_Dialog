# %% [markdown]
# # mein bericht

# %% [markdown]
# das ist meine abgabe

# %%
import requests
from eliza import eliza
import os
import json
from wendel_util import file_update

# %%
file_update()
vaccinations = open('vaccinations.json')
vaccinations = json.load(vaccinations)
# Out:
# Up To Date

# %%
vaccinations
# Out:
# {'data': {'administeredVaccinations': 73754612,
#   'vaccinated': 45307672,
#   'vaccination': {'biontech': 30621848,
#    'moderna': 3666375,
#    'astraZeneca': 9113473,
#    'janssen': 1905976},
#   'delta': 380213,
#   'quote': 0.545,
#   'secondVaccination': {'vaccinated': 30352916,
#    'vaccination': {'biontech': 23438440,
#     'moderna': 2694536,
#     'astraZeneca': 2313964,
#     'janssen': 1905976},
#    'delta': 527065,
#    'quote': 0.365},
#   'latestDailyVaccinations': {'date': '2021-06-29T00:00:00.000Z',
#    'vaccinated': 380213,
#    'firstVaccination': 380213,
#    'secondVaccination': 506773},
#   'indication': {'age': None,
#    'job': None,
#    'medical': None,
#    'nursingHome': None,
#    'secondVaccination': {'age': None,
#     'job': None,
#     'medical': None,
#     'nursingHome': None}},
#   'states': {'BW': {'name': 'Baden-Württemberg',
#     'administeredVaccinations': 9735267,
#     'vaccinated': 6000501,
#     'vaccination': {'biontech': 4107267,
#      'moderna': 506340,
#      'astraZeneca': 1160382,
#      'janssen': 226512},
#     'delta': 48312,
#     'quote': 0.541,
#     'secondVaccination': {'vaccinated': 3961278,
#      'vaccination': {'biontech': 3084350,
#       'moderna': 356747,
#       'astraZeneca': 293669,
#       'janssen': 226512},
#      'delta': 66071,
#      'quote': 0.35700000000000004},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BY': {'name': 'Bayern',
#     'administeredVaccinations': 11339457,
#     'vaccinated': 6804636,
#     'vaccination': {'biontech': 4715925,
#      'moderna': 540214,
#      'astraZeneca': 1304862,
#      'janssen': 243635},
#     'delta': 67601,
#     'quote': 0.518,
#     'secondVaccination': {'vaccinated': 4778456,
#      'vaccination': {'biontech': 3709376,
#       'moderna': 418578,
#       'astraZeneca': 406867,
#       'janssen': 243635},
#      'delta': 88054,
#      'quote': 0.364},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BE': {'name': 'Berlin',
#     'administeredVaccinations': 3206771,
#     'vaccinated': 1997712,
#     'vaccination': {'biontech': 1353473,
#      'moderna': 218737,
#      'astraZeneca': 355189,
#      'janssen': 70313},
#     'delta': 11526,
#     'quote': 0.544,
#     'secondVaccination': {'vaccinated': 1279372,
#      'vaccination': {'biontech': 981169,
#       'moderna': 131873,
#       'astraZeneca': 96017,
#       'janssen': 70313},
#      'delta': 24654,
#      'quote': 0.349},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BB': {'name': 'Brandenburg',
#     'administeredVaccinations': 2088906,
#     'vaccinated': 1313485,
#     'vaccination': {'biontech': 887694,
#      'moderna': 115696,
#      'astraZeneca': 247080,
#      'janssen': 63015},
#     'delta': 6649,
#     'quote': 0.521,
#     'secondVaccination': {'vaccinated': 838436,
#      'vaccination': {'biontech': 623327,
#       'moderna': 72377,
#       'astraZeneca': 79717,
#       'janssen': 63015},
#      'delta': 12685,
#      'quote': 0.332},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HB': {'name': 'Bremen',
#     'administeredVaccinations': 654418,
#     'vaccinated': 426109,
#     'vaccination': {'biontech': 286800,
#      'moderna': 23425,
#      'astraZeneca': 95402,
#      'janssen': 20482},
#     'delta': 3672,
#     'quote': 0.626,
#     'secondVaccination': {'vaccinated': 248791,
#      'vaccination': {'biontech': 192267,
#       'moderna': 18927,
#       'astraZeneca': 17115,
#       'janssen': 20482},
#      'delta': 3909,
#      'quote': 0.365},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HH': {'name': 'Hamburg',
#     'administeredVaccinations': 1573762,
#     'vaccinated': 970210,
#     'vaccination': {'biontech': 655662,
#      'moderna': 86206,
#      'astraZeneca': 184419,
#      'janssen': 43923},
#     'delta': 12926,
#     'quote': 0.525,
#     'secondVaccination': {'vaccinated': 647475,
#      'vaccination': {'biontech': 496413,
#       'moderna': 75979,
#       'astraZeneca': 31160,
#       'janssen': 43923},
#      'delta': 6903,
#      'quote': 0.35100000000000003},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HE': {'name': 'Hessen',
#     'administeredVaccinations': 5436158,
#     'vaccinated': 3371547,
#     'vaccination': {'biontech': 2282104,
#      'moderna': 257651,
#      'astraZeneca': 709464,
#      'janssen': 122328},
#     'delta': 26052,
#     'quote': 0.536,
#     'secondVaccination': {'vaccinated': 2186939,
#      'vaccination': {'biontech': 1688558,
#       'moderna': 194004,
#       'astraZeneca': 182049,
#       'janssen': 122328},
#      'delta': 39989,
#      'quote': 0.348},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'MV': {'name': 'Mecklenburg-Vorpommern',
#     'administeredVaccinations': 1462956,
#     'vaccinated': 880694,
#     'vaccination': {'biontech': 631588,
#      'moderna': 71443,
#      'astraZeneca': 144186,
#      'janssen': 33477},
#     'delta': 4845,
#     'quote': 0.5479999999999999,
#     'secondVaccination': {'vaccinated': 615739,
#      'vaccination': {'biontech': 493993,
#       'moderna': 48325,
#       'astraZeneca': 39944,
#       'janssen': 33477},
#      'delta': 10839,
#      'quote': 0.38299999999999995},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'NI': {'name': 'Niedersachsen',
#     'administeredVaccinations': 7035397,
#     'vaccinated': 4462210,
#     'vaccination': {'biontech': 2763730,
#      'moderna': 344247,
#      'astraZeneca': 1104190,
#      'janssen': 250043},
#     'delta': 48203,
#     'quote': 0.5579999999999999,
#     'secondVaccination': {'vaccinated': 2823230,
#      'vaccination': {'biontech': 2182470,
#       'moderna': 221033,
#       'astraZeneca': 169684,
#       'janssen': 250043},
#      'delta': 37411,
#      'quote': 0.353},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'NW': {'name': 'Nordrhein-Westfalen',
#     'administeredVaccinations': 16717154,
#     'vaccinated': 10193481,
#     'vaccination': {'biontech': 6793215,
#      'moderna': 675043,
#      'astraZeneca': 2229993,
#      'janssen': 495230},
#     'delta': 86800,
#     'quote': 0.568,
#     'secondVaccination': {'vaccinated': 7018903,
#      'vaccination': {'biontech': 5430353,
#       'moderna': 575024,
#       'astraZeneca': 518296,
#       'janssen': 495230},
#      'delta': 130838,
#      'quote': 0.391},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'RP': {'name': 'Rheinland-Pfalz',
#     'administeredVaccinations': 3609814,
#     'vaccinated': 2266130,
#     'vaccination': {'biontech': 1565203,
#      'moderna': 182304,
#      'astraZeneca': 426342,
#      'janssen': 92281},
#     'delta': 22114,
#     'quote': 0.5539999999999999,
#     'secondVaccination': {'vaccinated': 1435965,
#      'vaccination': {'biontech': 1108049,
#       'moderna': 110669,
#       'astraZeneca': 124966,
#       'janssen': 92281},
#      'delta': 28280,
#      'quote': 0.35100000000000003},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SL': {'name': 'Saarland',
#     'administeredVaccinations': 969657,
#     'vaccinated': 572147,
#     'vaccination': {'biontech': 427360,
#      'moderna': 39725,
#      'astraZeneca': 81930,
#      'janssen': 23132},
#     'delta': 5086,
#     'quote': 0.58,
#     'secondVaccination': {'vaccinated': 420642,
#      'vaccination': {'biontech': 347434,
#       'moderna': 29976,
#       'astraZeneca': 20100,
#       'janssen': 23132},
#      'delta': 5027,
#      'quote': 0.426},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SN': {'name': 'Sachsen',
#     'administeredVaccinations': 3341892,
#     'vaccinated': 1960467,
#     'vaccination': {'biontech': 1378970,
#      'moderna': 174955,
#      'astraZeneca': 345415,
#      'janssen': 61127},
#     'delta': 13111,
#     'quote': 0.48100000000000004,
#     'secondVaccination': {'vaccinated': 1442552,
#      'vaccination': {'biontech': 1105226,
#       'moderna': 156775,
#       'astraZeneca': 119424,
#       'janssen': 61127},
#      'delta': 24448,
#      'quote': 0.354},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'ST': {'name': 'Sachsen-Anhalt',
#     'administeredVaccinations': 1847644,
#     'vaccinated': 1137522,
#     'vaccination': {'biontech': 789043,
#      'moderna': 102236,
#      'astraZeneca': 188941,
#      'janssen': 57302},
#     'delta': 7683,
#     'quote': 0.518,
#     'secondVaccination': {'vaccinated': 767424,
#      'vaccination': {'biontech': 583363,
#       'moderna': 67324,
#       'astraZeneca': 59435,
#       'janssen': 57302},
#      'delta': 13350,
#      'quote': 0.35},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SH': {'name': 'Schleswig-Holstein',
#     'administeredVaccinations': 2692392,
#     'vaccinated': 1688016,
#     'vaccination': {'biontech': 1140936,
#      'moderna': 129447,
#      'astraZeneca': 349771,
#      'janssen': 67862},
#     'delta': 10368,
#     'quote': 0.581,
#     'secondVaccination': {'vaccinated': 1072238,
#      'vaccination': {'biontech': 824946,
#       'moderna': 85948,
#       'astraZeneca': 93482,
#       'janssen': 67862},
#      'delta': 19012,
#      'quote': 0.369},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'TH': {'name': 'Thüringen',
#     'administeredVaccinations': 1789960,
#     'vaccinated': 1098737,
#     'vaccination': {'biontech': 778226,
#      'moderna': 121647,
#      'astraZeneca': 167595,
#      'janssen': 31269},
#     'delta': 4704,
#     'quote': 0.515,
#     'secondVaccination': {'vaccinated': 722492,
#      'vaccination': {'biontech': 574099,
#       'moderna': 63268,
#       'astraZeneca': 53856,
#       'janssen': 31269},
#      'delta': 13572,
#      'quote': 0.33899999999999997},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'Bund': {'name': 'Bundesressorts',
#     'administeredVaccinations': 253007,
#     'vaccinated': 164068,
#     'vaccination': {'biontech': 64652,
#      'moderna': 77059,
#      'astraZeneca': 18312,
#      'janssen': 4045},
#     'delta': 561,
#     'quote': None,
#     'secondVaccination': {'vaccinated': 92984,
#      'vaccination': {'biontech': 13047,
#       'moderna': 67709,
#       'astraZeneca': 8183,
#       'janssen': 4045},
#      'delta': 2023,
#      'quote': None},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}}}},
#  'meta': {'source': 'Robert Koch-Institut',
#   'contact': 'Marlon Lueckert (m.lueckert@me.com)',
#   'info': 'https://github.com/marlon360/rki-covid-api',
#   'lastUpdate': '2021-06-30T07:57:25.000Z',
#   'lastCheckedForUpdate': '2021-06-30T10:06:42.217Z'}}

# %%
states_d = {'schleswig':'SH', 'hamburg':'HH', 'berlin':'BE', 'bayern':'BY', 
            'niedersachsen': 'NI', 'bremen': 'HB', 
            'nordrhein':'NW', 'hessen':'HE', 'rheinland':'RP', 'baden':'BW', 
            'saarland': 'SL', 'brandenburg':'BB', 'mecklenburg':'MV', 'sachsen':'SN',
            'anhalt':'ST', 'thüringen':'TH', 'deutschland':'DE', 'hier':'DE'}
state_names = {'SH':'Schleswig-Hostein', 'HH':'Hamburg', 'BE':'Berlin', 'BY':'Bayern', 
            'NI':'Niedersachsen', 'HB':'Bremen', 
            'NW': 'Nordrhein Westphalen', 'HE':'Hessen', 'RP':'Rheinland Pfalz', 'BW':'Baden Würthenberg', 
            'SL':'Saarland', 'BB':'Brandenburg', 'MV':'Mecklenburg Vorpommern', 
            'SN': 'Sachsen', 'ST':'Sachsen-Anhalt', 'TH':'Thüringen', 'DE':'Deutschland'}
vaccines_d = {'biontech':'biontech', 'biontec':'biontech', 
              'moderna':'moderna', 
              'janssen':'janssen', 'jansen':'janssen',
              'delta':'delta',
              'astraZeneca':'astraZeneca', 'astra':'astraZeneca', 'zeneca':'astraZeneca'}
vaccine_names = {'biontech':'Biontech', 'moderna':'Moderna', 'janssen':'Janssen', 'delta':'Delta',
              'astraZeneca':'Astra Zeneca'}

# %%
def normalize(in_s):
    # e.g. remove stopwords, lemmatization, stemming, 
    return in_s.lower()

# %%
def do_input():
    return input('> ')

# %%
def semantic(input_s):
    semantics = {'state':'', 'vaccine':'', 'answer':0}
    for key in states_d.keys():
        if key in input_s:
            semantics['state'] = states_d[key]
            break
    for key in  vaccines_d.keys():
        if key in input_s:
            semantics['vaccine'] =  vaccines_d[key]
            break
    return semantics

# %%
# expects semantics: semantics[0] == bundesland, semantics[1] == impfstoff 
def data(semantics):
    s = semantics['state']
    v = semantics['vaccine']
    if s: # state given
        if s != 'DE':
            if v: # and vaccine given
                semantics['answer'] = vaccinations["data"]["states"][s]['vaccination'][v]
            else: # all vaccines for state
                semantics['answer'] = vaccinations["data"]["states"][s]['vaccinated']
        else:
            if v: # and vaccine given
                semantics['answer'] = vaccinations["data"]['vaccination'][v]
            else: # all vaccines for Germany
                semantics['answer'] = vaccinations['data']['vaccinated']
    else: # no state
        if v: # but vaccine
            semantics['answer'] = vaccinations["data"]['vaccination'][v]
        else: # nothing given
            semantics['answer'] = None
    return semantics

# %%
vaccine_names

# %%
def output(semantics, inputs):
    ret = ''
    s = semantics['state']
    v = semantics['vaccine']
    a = semantics['answer']
    if s: # state given
        s = state_names[s]
        if v: # and vaccine given
            v = vaccine_names[v]
            ret = 'Die Impfungen für {} mit {} sind {}'.format(s, v, a)
        else: # all vaccines for state
            ret = 'Die Impfungen für {} sind {}'.format(s, a)
    else: # no state
        if v: # but vaccine
            v = vaccine_names[v]
            ret = 'Die Impfungen in Deutschland mit {} sind {}'.format(v, a)
        else: # nothing given
            ret =  elz.respond(inputs)
    return ret

# %%
def init_eliza():
    root = r'/home/felix/data/TU/SS2021/S_dialog/'
    elz = eliza.Eliza()
    elz.load(root+'/eliza/deutsch.txt')
    return elz

# %%
def dialogmanager():
    print("Frag was!")
    input_s = do_input()
    input_s = normalize(input_s)
    while input_s and input_s != 'fertig':
        semantics = semantic(input_s)
        semantics = data(semantics)
        out_string = output(semantics, input_s)
        print(out_string)
        input_s = do_input()
        input_s = normalize(input_s)

# %%
elz = init_eliza()
dialogmanager()
# Out:
# Frag was!
# > wie geht?
# Ich bin nicht sicher, ob ich dich verstanden habe.
# > berlin
# Die Impfungen für Berlin sind 1997712
# > huhu?
# Erzähl mir weiter.
# > bayern mit biontec
# Die Impfungen für Bayern mit Biontech sind 4715925
# >

# %%
vaccinations.json()

# %%
vacc_number = vaccinations.json()["data"]["states"]['BY']['vaccinated']

# %%
data.json()["data"]['SH']['cases']

# %%
data.json()

# %%
vaccinations = requests.get('https://api.corona-zahlen.org/germany')

# %%
data = requests.get('https://api.corona-zahlen.org/states')

# %%
vaccinations
