# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in ./venv/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.8/site-packages (from requests) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./venv/lib/python3.8/site-packages (from requests) (4.0.0)
# WARNING: You are using pip version 19.2.3, however version 21.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import requests

# %%
corona_numbers = requests.get('https://api.corona-zahlen.org/germany')

# %%
vaccinations = requests.get('https://api.corona-zahlen.org/vaccinations')

# %%
vaccinations
# Out:
# <Response [200]>

# %%
corona_numbers
# Out:
# <Response [200]>

# %%
vaccinations.json()
# Out:
# {'data': {'administeredVaccinations': 67116671,
#   'vaccinated': 42540863,
#   'vaccination': {'biontech': 28427415,
#    'moderna': 3427740,
#    'astraZeneca': 8987362,
#    'janssen': 1698346},
#   'delta': 219325,
#   'quote': 0.512,
#   'secondVaccination': {'vaccinated': 26274154,
#    'vaccination': {'biontech': 20725544,
#     'moderna': 2257414,
#     'astraZeneca': 1592850,
#     'janssen': 1698346},
#    'delta': 398920,
#    'quote': 0.316},
#   'latestDailyVaccinations': {'date': '2021-06-21T00:00:00.000Z',
#    'vaccinated': 219325,
#    'firstVaccination': 219325,
#    'secondVaccination': 363244},
#   'indication': {'age': None,
#    'job': None,
#    'medical': None,
#    'nursingHome': None,
#    'secondVaccination': {'age': None,
#     'job': None,
#     'medical': None,
#     'nursingHome': None}},
#   'states': {'BW': {'name': 'Baden-Württemberg',
#     'administeredVaccinations': 8863643,
#     'vaccinated': 5631855,
#     'vaccination': {'biontech': 3800665,
#      'moderna': 483183,
#      'astraZeneca': 1148521,
#      'janssen': 199486},
#     'delta': 29981,
#     'quote': 0.507,
#     'secondVaccination': {'vaccinated': 3431274,
#      'vaccination': {'biontech': 2726578,
#       'moderna': 299053,
#       'astraZeneca': 206157,
#       'janssen': 199486},
#      'delta': 50938,
#      'quote': 0.309},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BY': {'name': 'Bayern',
#     'administeredVaccinations': 10192572,
#     'vaccinated': 6317516,
#     'vaccination': {'biontech': 4347874,
#      'moderna': 469187,
#      'astraZeneca': 1287857,
#      'janssen': 212598},
#     'delta': 37896,
#     'quote': 0.48100000000000004,
#     'secondVaccination': {'vaccinated': 4087654,
#      'vaccination': {'biontech': 3212769,
#       'moderna': 357761,
#       'astraZeneca': 304526,
#       'janssen': 212598},
#      'delta': 62978,
#      'quote': 0.311},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BE': {'name': 'Berlin',
#     'administeredVaccinations': 2936047,
#     'vaccinated': 1898578,
#     'vaccination': {'biontech': 1274376,
#      'moderna': 207298,
#      'astraZeneca': 353289,
#      'janssen': 63615},
#     'delta': 10960,
#     'quote': 0.517,
#     'secondVaccination': {'vaccinated': 1101084,
#      'vaccination': {'biontech': 867159,
#       'moderna': 101111,
#       'astraZeneca': 69199,
#       'janssen': 63615},
#      'delta': 19029,
#      'quote': 0.3},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BB': {'name': 'Brandenburg',
#     'administeredVaccinations': 1936520,
#     'vaccinated': 1259622,
#     'vaccination': {'biontech': 844453,
#      'moderna': 112609,
#      'astraZeneca': 245990,
#      'janssen': 56570},
#     'delta': 5768,
#     'quote': 0.499,
#     'secondVaccination': {'vaccinated': 733468,
#      'vaccination': {'biontech': 554558,
#       'moderna': 61507,
#       'astraZeneca': 60833,
#       'janssen': 56570},
#      'delta': 11436,
#      'quote': 0.29100000000000004},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HB': {'name': 'Bremen',
#     'administeredVaccinations': 594553,
#     'vaccinated': 394470,
#     'vaccination': {'biontech': 258835,
#      'moderna': 22963,
#      'astraZeneca': 95127,
#      'janssen': 17545},
#     'delta': 2912,
#     'quote': 0.579,
#     'secondVaccination': {'vaccinated': 217628,
#      'vaccination': {'biontech': 172790,
#       'moderna': 16301,
#       'astraZeneca': 10992,
#       'janssen': 17545},
#      'delta': 2791,
#      'quote': 0.319},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HH': {'name': 'Hamburg',
#     'administeredVaccinations': 1419460,
#     'vaccinated': 896349,
#     'vaccination': {'biontech': 595298,
#      'moderna': 82044,
#      'astraZeneca': 180588,
#      'janssen': 38419},
#     'delta': 4221,
#     'quote': 0.485,
#     'secondVaccination': {'vaccinated': 561530,
#      'vaccination': {'biontech': 443332,
#       'moderna': 63946,
#       'astraZeneca': 15833,
#       'janssen': 38419},
#      'delta': 10547,
#      'quote': 0.304},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HE': {'name': 'Hessen',
#     'administeredVaccinations': 4939875,
#     'vaccinated': 3182061,
#     'vaccination': {'biontech': 2137250,
#      'moderna': 238868,
#      'astraZeneca': 699499,
#      'janssen': 106444},
#     'delta': 13747,
#     'quote': 0.506,
#     'secondVaccination': {'vaccinated': 1864258,
#      'vaccination': {'biontech': 1461624,
#       'moderna': 160071,
#       'astraZeneca': 136119,
#       'janssen': 106444},
#      'delta': 28607,
#      'quote': 0.29600000000000004},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'MV': {'name': 'Mecklenburg-Vorpommern',
#     'administeredVaccinations': 1356063,
#     'vaccinated': 842135,
#     'vaccination': {'biontech': 598492,
#      'moderna': 69938,
#      'astraZeneca': 143587,
#      'janssen': 30118},
#     'delta': 4215,
#     'quote': 0.524,
#     'secondVaccination': {'vaccinated': 544046,
#      'vaccination': {'biontech': 446279,
#       'moderna': 39299,
#       'astraZeneca': 28350,
#       'janssen': 30118},
#      'delta': 8582,
#      'quote': 0.33799999999999997},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'NI': {'name': 'Niedersachsen',
#     'administeredVaccinations': 6413512,
#     'vaccinated': 4163065,
#     'vaccination': {'biontech': 2570219,
#      'moderna': 283204,
#      'astraZeneca': 1081399,
#      'janssen': 228243},
#     'delta': 22750,
#     'quote': 0.521,
#     'secondVaccination': {'vaccinated': 2478690,
#      'vaccination': {'biontech': 1919430,
#       'moderna': 202268,
#       'astraZeneca': 128749,
#       'janssen': 228243},
#      'delta': 44181,
#      'quote': 0.31},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'NW': {'name': 'Nordrhein-Westfalen',
#     'administeredVaccinations': 15190632,
#     'vaccinated': 9589714,
#     'vaccination': {'biontech': 6284987,
#      'moderna': 662622,
#      'astraZeneca': 2198855,
#      'janssen': 443250},
#     'delta': 39008,
#     'quote': 0.534,
#     'secondVaccination': {'vaccinated': 6044168,
#      'vaccination': {'biontech': 4827427,
#       'moderna': 466940,
#       'astraZeneca': 306551,
#       'janssen': 443250},
#      'delta': 87790,
#      'quote': 0.337},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'RP': {'name': 'Rheinland-Pfalz',
#     'administeredVaccinations': 3259073,
#     'vaccinated': 2104049,
#     'vaccination': {'biontech': 1428136,
#      'moderna': 179827,
#      'astraZeneca': 416749,
#      'janssen': 79337},
#     'delta': 15303,
#     'quote': 0.514,
#     'secondVaccination': {'vaccinated': 1234361,
#      'vaccination': {'biontech': 997459,
#       'moderna': 87801,
#       'astraZeneca': 69764,
#       'janssen': 79337},
#      'delta': 15905,
#      'quote': 0.302},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SL': {'name': 'Saarland',
#     'administeredVaccinations': 891685,
#     'vaccinated': 537323,
#     'vaccination': {'biontech': 400250,
#      'moderna': 36554,
#      'astraZeneca': 80644,
#      'janssen': 19875},
#     'delta': 2573,
#     'quote': 0.544,
#     'secondVaccination': {'vaccinated': 374237,
#      'vaccination': {'biontech': 312034,
#       'moderna': 26506,
#       'astraZeneca': 15822,
#       'janssen': 19875},
#      'delta': 6601,
#      'quote': 0.379},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SN': {'name': 'Sachsen',
#     'administeredVaccinations': 3073917,
#     'vaccinated': 1850975,
#     'vaccination': {'biontech': 1287645,
#      'moderna': 165846,
#      'astraZeneca': 341060,
#      'janssen': 56424},
#     'delta': 7969,
#     'quote': 0.455,
#     'secondVaccination': {'vaccinated': 1279366,
#      'vaccination': {'biontech': 1008813,
#       'moderna': 142876,
#       'astraZeneca': 71253,
#       'janssen': 56424},
#      'delta': 17541,
#      'quote': 0.314},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'ST': {'name': 'Sachsen-Anhalt',
#     'administeredVaccinations': 1695210,
#     'vaccinated': 1072921,
#     'vaccination': {'biontech': 735594,
#      'moderna': 97451,
#      'astraZeneca': 186948,
#      'janssen': 52928},
#     'delta': 6321,
#     'quote': 0.489,
#     'secondVaccination': {'vaccinated': 675217,
#      'vaccination': {'biontech': 520032,
#       'moderna': 57928,
#       'astraZeneca': 44329,
#       'janssen': 52928},
#      'delta': 12388,
#      'quote': 0.308},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SH': {'name': 'Schleswig-Holstein',
#     'administeredVaccinations': 2469465,
#     'vaccinated': 1593753,
#     'vaccination': {'biontech': 1071906,
#      'moderna': 118854,
#      'astraZeneca': 341897,
#      'janssen': 61096},
#     'delta': 8760,
#     'quote': 0.5489999999999999,
#     'secondVaccination': {'vaccinated': 936808,
#      'vaccination': {'biontech': 735169,
#       'moderna': 73377,
#       'astraZeneca': 67166,
#       'janssen': 61096},
#      'delta': 12415,
#      'quote': 0.32299999999999995},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'TH': {'name': 'Thüringen',
#     'administeredVaccinations': 1657338,
#     'vaccinated': 1051853,
#     'vaccination': {'biontech': 735140,
#      'moderna': 121091,
#      'astraZeneca': 167023,
#      'janssen': 28599},
#     'delta': 5518,
#     'quote': 0.493,
#     'secondVaccination': {'vaccinated': 634084,
#      'vaccination': {'biontech': 515163,
#       'moderna': 41150,
#       'astraZeneca': 49172,
#       'janssen': 28599},
#      'delta': 6318,
#      'quote': 0.297},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'Bund': {'name': 'Bundesressorts',
#     'administeredVaccinations': 227106,
#     'vaccinated': 154624,
#     'vaccination': {'biontech': 56295,
#      'moderna': 76201,
#      'astraZeneca': 18329,
#      'janssen': 3799},
#     'delta': 1423,
#     'quote': None,
#     'secondVaccination': {'vaccinated': 76281,
#      'vaccination': {'biontech': 4928,
#       'moderna': 59519,
#       'astraZeneca': 8035,
#       'janssen': 3799},
#      'delta': 873,
#      'quote': None},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}}}},
#  'meta': {'source': 'Robert Koch-Institut',
#   'contact': 'Marlon Lueckert (m.lueckert@me.com)',
#   'info': 'https://github.com/marlon360/rki-covid-api',
#   'lastUpdate': '2021-06-22T07:57:32.000Z',
#   'lastCheckedForUpdate': '2021-06-23T08:00:10.093Z'}}
